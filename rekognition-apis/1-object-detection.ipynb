# %% [markdown]
# # Object and scene detection using Amazon Rekognition

# %% [markdown]
# ***
# This notebook provides a walkthrough of [object detection API](https://docs.aws.amazon.com/rekognition/latest/dg/labels.html) in Amazon Rekognition to identify objects.
# ***

# %% [markdown]
# # Initialize stuff

# %%
# Initialise Notebook
import boto3
from IPython.display import HTML, display, Image as IImage
from PIL import Image, ImageDraw, ImageFont
import time
import os

# %%
# Curent AWS Region. Use this to choose corresponding S3 bucket with sample content

mySession = boto3.session.Session()
awsRegion = mySession.region_name

# %%
# Init clients
rekognition = boto3.client('rekognition')
s3 = boto3.client('s3')

# %%
# S3 bucket that contains sample images and videos

# We are providing sample images and videos in this bucket so
# you do not have to manually download/upload test images and videos.

bucketName = "aws-rek-immersionday-" + awsRegion

# %%
# Create temporary directory
# This directory is not needed to call Rekognition APIs.
# We will only use this directory to download images from S3 bucket and draw bounding boxes

# !mkdir m1tmp
tempFolder = 'm1tmp/'
# Out:
# mkdir: cannot create directory ‘m1tmp’: File exists

# %% [markdown]
# # Detect objects in image
# ***

# %%
imageName = "media/object-detection/cars.png"

# %%
display(IImage(url=s3.generate_presigned_url('get_object', Params={'Bucket': bucketName, 'Key': imageName})))
# Out:
# <img src="https://aws-rek-immersionday-us-east-1.s3.amazonaws.com/media/object-detection/cars.png?AWSAccessKeyId=ASIA6AX7UATUEHFSDD74&Signature=g%2BhqgADuBRhzHtVq7kTDIgZWBNw%3D&x-amz-security-token=IQoJb3JpZ2luX2VjECcaCXVzLWVhc3QtMSJHMEUCIQC%2BsyMqdGPe67OFtj5x2XHJmty0plTVN1i4zMK8TxfPHwIgTAZOaEwOUwMZ0RT0fkl9uTfe3cE9ee7slgKehlsp1PYqigMIgP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARABGgw5NjM2ODI1MDE4NjQiDP%2Fw0ytWD4VFo8Gn9yreAnq%2BiFqp0LE%2FwwWqpLiM1qa7GkmLwzQoVoSDf41eqR8LTe8XZGQqJHK%2FHUPo6MQBnH0%2BIeiZs2cgTedr1Ik0url5AryD6OEdUWTzwzF1FSDgmErqckXy2%2BUD9BOArwESdfHazAEJMMcJ919CM5fMDUGdBTswNiKf7uBYXxGNkBpLVicErtLA6TuEKUsXHxs8aOxHNec2xvwnyvIPI8l0zBhaS1MlKTyjnku2Q6WcVniLHrBCulv0XYmMvamIb2GqFc1J2oL0FdHODTkmFvSN6UUFP8SoR7LONZ8N%2FtzGl97%2FYJgcFVwc76fWi8tVHtc8AyyPZwFeJGSdxgI1F90QZTQw39Eu7801kvjd%2BGtpA9saGfmq7wBWIJnX0DT8i3vuD9uDkEkQ8JMzzbAQv5nyq7ex9uwUxCjhGFDo6leBpQyep6YPwNeMjDRwXAp8zNfyS88vMppiXhK4fCywg7YQMMmWvqQGOpsBUcNSbhpyIRY2ckpwHX%2BBoC64t0%2Blo5%2FKfI7gP51tpKgFlycmrBrmzDME19sgvi4J4MOiMxQwBoEiKZr0Hwmf55VyrFjWkj%2BhL0bBsBd7K%2B8P1SHX9%2FRC7OC3Jq%2FNuupdhUWSaj8aP7yqH7S8VCZvZHc8lzvXvTHwGeN7asptFzqi%2BdJhN5QVuW4QmFDV5hRcfA8RqARvHTyP86E%3D&Expires=1687134130"/>

# %% [markdown]
# #### Call Rekognition to detect objects in the image

# %%
# Call Amazon Rekognition to detect objects in the image
# https://docs.aws.amazon.com/rekognition/latest/dg/API_DetectLabels.html

detectLabelsResponse = rekognition.detect_labels(
    Image={
        'S3Object': {
            'Bucket': bucketName,
            'Name': imageName,
        }
    }
)

# %% [markdown]
# #### Review the raw JSON reponse from Rekognition

# %%
# Show JSON response returned by Rekognition Labels API (Object Detection)
# In the JSON response below, you will see Label, detected instances, confidence score and additional information.

display(detectLabelsResponse)
# Out:
# {'Labels': [{'Name': 'Car',
#    'Confidence': 99.32563018798828,
#    'Instances': [{'BoundingBox': {'Width': 0.2200002670288086,
#       'Height': 0.13564352691173553,
#       'Left': 0.5040069222450256,
#       'Top': 0.5871573686599731},
#      'Confidence': 99.32563018798828},
#     {'BoundingBox': {'Width': 0.25349944829940796,
#       'Height': 0.1738702654838562,
#       'Left': 0.18528205156326294,
#       'Top': 0.5684974789619446},
#      'Confidence': 99.28734588623047}],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [{'Name': 'Automobile'}],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Transportation',
#    'Confidence': 99.32563018798828,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Vehicle',
#    'Confidence': 99.32563018798828,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Machine',
#    'Confidence': 96.39551544189453,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Tools and Machinery'}]},
#   {'Name': 'Wheel',
#    'Confidence': 96.39551544189453,
#    'Instances': [{'BoundingBox': {'Width': 0.024530459195375443,
#       'Height': 0.0891716256737709,
#       'Left': 0.18841950595378876,
#       'Top': 0.6245220303535461},
#      'Confidence': 96.39551544189453},
#     {'BoundingBox': {'Width': 0.03203301504254341,
#       'Height': 0.07088232040405273,
#       'Left': 0.5057023167610168,
#       'Top': 0.6328112483024597},
#      'Confidence': 96.0383071899414},
#     {'BoundingBox': {'Width': 0.02819645404815674,
#       'Height': 0.09699912369251251,
#       'Left': 0.273847758769989,
#       'Top': 0.6394572854042053},
#      'Confidence': 95.67852783203125},
#     {'BoundingBox': {'Width': 0.031245995312929153,
#       'Height': 0.07009632140398026,
#       'Left': 0.6064748764038086,
#       'Top': 0.6487252116203308},
#      'Confidence': 95.6663818359375}],
#    'Parents': [{'Name': 'Machine'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Alloy Wheel',
#    'Confidence': 95.72265625,
#    'Instances': [],
#    'Parents': [{'Name': 'Car'},
#     {'Name': 'Car Wheel'},
#     {'Name': 'Machine'},
#     {'Name': 'Spoke'},
#     {'Name': 'Tire'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'},
#     {'Name': 'Wheel'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Car Wheel',
#    'Confidence': 95.72265625,
#    'Instances': [],
#    'Parents': [{'Name': 'Car'},
#     {'Name': 'Machine'},
#     {'Name': 'Tire'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'},
#     {'Name': 'Wheel'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Spoke',
#    'Confidence': 95.72265625,
#    'Instances': [],
#    'Parents': [{'Name': 'Machine'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Tire',
#    'Confidence': 95.72265625,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Road',
#    'Confidence': 82.59342956542969,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Transport and Logistics'}]},
#   {'Name': 'Tarmac',
#    'Confidence': 79.1739730834961,
#    'Instances': [],
#    'Parents': [{'Name': 'Road'}],
#    'Aliases': [{'Name': 'Asphalt'}],
#    'Categories': [{'Name': 'Transport and Logistics'}]},
#   {'Name': 'Adventure',
#    'Confidence': 69.08169555664062,
#    'Instances': [],
#    'Parents': [{'Name': 'Leisure Activities'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Travel and Adventure'}]},
#   {'Name': 'Leisure Activities',
#    'Confidence': 69.08169555664062,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [{'Name': 'Recreation'}],
#    'Categories': [{'Name': 'Travel and Adventure'}]},
#   {'Name': 'Race Car',
#    'Confidence': 67.72917175292969,
#    'Instances': [],
#    'Parents': [{'Name': 'Sport'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Sport',
#    'Confidence': 67.72917175292969,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [{'Name': 'Sports'}],
#    'Categories': [{'Name': 'Sports'}]},
#   {'Name': 'Auto Racing',
#    'Confidence': 58.47364807128906,
#    'Instances': [],
#    'Parents': [{'Name': 'Car'},
#     {'Name': 'Race Car'},
#     {'Name': 'Sport'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Travel and Adventure'}]},
#   {'Name': 'Sports Car',
#    'Confidence': 57.22043991088867,
#    'Instances': [],
#    'Parents': [{'Name': 'Car'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Offroad',
#    'Confidence': 56.49694061279297,
#    'Instances': [],
#    'Parents': [{'Name': 'Adventure'},
#     {'Name': 'Leisure Activities'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Rally',
#    'Confidence': 56.49694061279297,
#    'Instances': [],
#    'Parents': [{'Name': 'Adventure'},
#     {'Name': 'Auto Racing'},
#     {'Name': 'Car'},
#     {'Name': 'Leisure Activities'},
#     {'Name': 'Offroad'},
#     {'Name': 'Race Car'},
#     {'Name': 'Sport'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'}],
#    'Aliases': [{'Name': 'Rally Racing'}],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Coupe',
#    'Confidence': 56.43541717529297,
#    'Instances': [],
#    'Parents': [{'Name': 'Car'},
#     {'Name': 'Sports Car'},
#     {'Name': 'Transportation'},
#     {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]}],
#  'LabelModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '7d1a4585-29a8-4ba5-ab91-9e1b18047d11',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '7d1a4585-29a8-4ba5-ab91-9e1b18047d11',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4799',
#    'date': 'Sun, 18 Jun 2023 23:22:11 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### Display list of detected unsafe objects}

# %%
flaggedObjects = ["Car"]

for label in detectLabelsResponse["Labels"]:
    if(label["Name"] in flaggedObjects):
        print("Detected unsafe object:")
        print("- {} (Confidence: {})".format(label["Name"], label["Confidence"]))
        print("  - Parents: {}".format(label["Parents"]))
# Out:
# Detected unsafe object:
# - Car (Confidence: 99.32563018798828)
#   - Parents: [{'Name': 'Transportation'}, {'Name': 'Vehicle'}]

# %%
# Define a function that will display image with bounded boxes around recognized objects
# We will call this function in next step
  
def drawBoundingBoxes (sourceImage, boxes):
    # blue, green, red, grey
    colors = ((255,255,255),(255,255,255),(76,182,252),(52,194,123))
    
    # Download image locally
    imageLocation = tempFolder+os.path.basename(sourceImage)
    s3.download_file(bucketName, sourceImage, imageLocation)

    # Draws BB on Image
    bbImage = Image.open(imageLocation)
    draw = ImageDraw.Draw(bbImage)
    width, height = bbImage.size
    col = 0
    maxcol = len(colors)
    line= 3
    for box in boxes:
        x1 = int(box[1]['Left'] * width)
        y1 = int(box[1]['Top'] * height)
        x2 = int(box[1]['Left'] * width + box[1]['Width'] * width)
        y2 = int(box[1]['Top'] * height + box[1]['Height']  * height)
        
        draw.text((x1,y1),box[0],colors[col])
        for l in range(line):
            draw.rectangle((x1-l,y1-l,x2+l,y2+l),outline=colors[col])
        col = (col+1)%maxcol
    
    imageFormat = "PNG"
    ext = sourceImage.lower()
    if(ext.endswith('jpg') or ext.endswith('jpeg')):
        imageFormat = 'JPEG'

    bbImage.save(imageLocation,format=imageFormat)

    display(bbImage)

# %%
# Show image and bounded boxes around detected objects
boxes = []
objects = detectLabelsResponse['Labels']
for obj in objects:
    for einstance in obj["Instances"]:
        boxes.append ((obj['Name'], einstance['BoundingBox']))
    
drawBoundingBoxes(imageName, boxes)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x704>

# %% [markdown]
# # Recognize objects in video
#  Object recognition in video is an async operation.
# https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html.
#
# - First we start a label detection job which returns a Job Id.
# - We can then call `get_label_detection` to get the job status and after job is complete, we can get object metadata.
# - In production use cases, you would usually use StepFunction or SNS topic to get notified when job is complete.
# ***

# %%
videoName = "media/object-detection/GrandTour720.mp4"

# %% [markdown]
# #### Call Rekognition to start a job for object detection

# %%
# Start video label recognition job
startLabelDetection = rekognition.start_label_detection(
    Video={
        'S3Object': {
            'Bucket': bucketName,
            'Name': videoName,
        }
    },
)

labelsJobId = startLabelDetection['JobId']
display("Job Id: {0}".format(labelsJobId))
# Out:
# 'Job Id: 552e1b53d0fc18614773fde309f8df17e3a99281f66cbe5678b8087d5a66665e'

# %% [markdown]
# ### Additional (Optional) Request Attributes
#
# ClientRequestTokenL
# https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html#rekognition-StartLabelDetection-request-ClientRequestToken
#
# JobTag:
# https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html#rekognition-StartLabelDetection-request-JobTag
#
# MinConfidence:
# https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html#rekognition-StartLabelDetection-request-MinConfidence
#
# NotificationChannel:
# https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html#rekognition-StartLabelDetection-request-NotificationChannel

# %% [markdown]
# #### Wait for object detection job to complete

# %%
# Wait for object detection job to complete
# In production use cases, you would usually use StepFunction or SNS topic to get notified when job is complete.
getObjectDetection = rekognition.get_label_detection(
    JobId=labelsJobId,
    SortBy='TIMESTAMP'
)

while(getObjectDetection['JobStatus'] == 'IN_PROGRESS'):
    time.sleep(5)
    print('.', end='')
 
    getObjectDetection = rekognition.get_label_detection(
    JobId=labelsJobId,
    SortBy='TIMESTAMP')
    
display(getObjectDetection['JobStatus'])
# Out:
# ....
# 'SUCCEEDED'

# %% [markdown]
# #### Review raw JSON reponse from Rekognition

# %%
# Show JSON response returned by Rekognition Object Detection API
# In the JSON response below, you will see list of detected objects and activities.
# For each detected object, you will see information like Timestamp

display(getObjectDetection)
# Out:
# {'JobStatus': 'SUCCEEDED',
#  'VideoMetadata': {'Codec': 'h264',
#   'DurationMillis': 15015,
#   'Format': 'QuickTime / MOV',
#   'FrameRate': 23.976024627685547,
#   'FrameHeight': 720,
#   'FrameWidth': 1280,
#   'ColorRange': 'LIMITED'},
#  'Labels': [{'Timestamp': 0,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 57.64604568481445,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Animal',
#     'Confidence': 50.819156646728516,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Baseball',
#     'Confidence': 50.28710174560547,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [{'Name': 'Softball'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Car',
#     'Confidence': 60.74497985839844,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 57.64604568481445,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Clothing',
#     'Confidence': 52.093936920166016,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Apparel'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Electrical Device',
#     'Confidence': 51.353981018066406,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Electronics',
#     'Confidence': 51.2313346862793,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Glove',
#     'Confidence': 52.093936920166016,
#     'Instances': [],
#     'Parents': [{'Name': 'Clothing'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Gray',
#     'Confidence': 76.63156127929688,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Colors and Visual Composition'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Leisure Activities',
#     'Confidence': 55.93943405151367,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Recreation'}],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Machine',
#     'Confidence': 59.92033386230469,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Mammal',
#     'Confidence': 50.652957916259766,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Nature',
#     'Confidence': 51.7252082824707,
#     'Instances': [],
#     'Parents': [{'Name': 'Outdoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Outdoors',
#     'Confidence': 51.7252082824707,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Person',
#     'Confidence': 51.801353454589844,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Racket',
#     'Confidence': 56.77547073364258,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Road',
#     'Confidence': 52.836612701416016,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Snow',
#     'Confidence': 51.13283157348633,
#     'Instances': [],
#     'Parents': [{'Name': 'Nature'}, {'Name': 'Outdoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 57.64604568481445,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Sport',
#     'Confidence': 58.655303955078125,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Sports'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Tennis',
#     'Confidence': 53.72113800048828,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Tennis Racket',
#     'Confidence': 53.72113800048828,
#     'Instances': [],
#     'Parents': [{'Name': 'Racket'}, {'Name': 'Sport'}, {'Name': 'Tennis'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Text',
#     'Confidence': 55.93224334716797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Text and Documents'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Tire',
#     'Confidence': 57.64604568481445,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 60.74497985839844,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 60.74497985839844,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 0,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 59.92033386230469,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Adventure',
#     'Confidence': 78.91826629638672,
#     'Instances': [],
#     'Parents': [{'Name': 'Leisure Activities'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 82.33280944824219,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Auto Racing',
#     'Confidence': 69.30732727050781,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Bicycle',
#     'Confidence': 50.549068450927734,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Bike'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Car',
#     'Confidence': 95.09324645996094,
#     'Instances': [{'BoundingBox': {'Width': 0.25284847617149353,
#        'Height': 0.16762462258338928,
#        'Left': 0.1870129555463791,
#        'Top': 0.5590078234672546},
#       'Confidence': 99.49807739257812},
#      {'BoundingBox': {'Width': 0.21909603476524353,
#        'Height': 0.12907032668590546,
#        'Left': 0.5043258666992188,
#        'Top': 0.5778445601463318},
#       'Confidence': 99.42863464355469}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 82.33280944824219,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Leisure Activities',
#     'Confidence': 83.67257690429688,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Recreation'}],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Machine',
#     'Confidence': 90.3739242553711,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Offroad',
#     'Confidence': 62.723751068115234,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Person',
#     'Confidence': 50.75975799560547,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Race Car',
#     'Confidence': 73.7031021118164,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Racket',
#     'Confidence': 51.621917724609375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Rally',
#     'Confidence': 62.706764221191406,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Auto Racing'},
#      {'Name': 'Car'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Offroad'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Rally Racing'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Road',
#     'Confidence': 65.33753967285156,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 82.33280944824219,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Sport',
#     'Confidence': 78.87086486816406,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Sports'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Sports Car',
#     'Confidence': 50.60908508300781,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Tarmac',
#     'Confidence': 52.60220718383789,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [{'Name': 'Asphalt'}],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Tennis',
#     'Confidence': 51.276485443115234,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Tennis Racket',
#     'Confidence': 51.276485443115234,
#     'Instances': [],
#     'Parents': [{'Name': 'Racket'}, {'Name': 'Sport'}, {'Name': 'Tennis'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Tire',
#     'Confidence': 82.33280944824219,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 95.09324645996094,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 95.09324645996094,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 500,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 90.3739242553711,
#     'Instances': [{'BoundingBox': {'Width': 0.02760462835431099,
#        'Height': 0.09479378908872604,
#        'Left': 0.2750518023967743,
#        'Top': 0.6257571578025818},
#       'Confidence': 94.0499267578125},
#      {'BoundingBox': {'Width': 0.032143689692020416,
#        'Height': 0.06848805397748947,
#        'Left': 0.6061921119689941,
#        'Top': 0.635721743106842},
#       'Confidence': 93.91041564941406},
#      {'BoundingBox': {'Width': 0.02458825148642063,
#        'Height': 0.08791448920965195,
#        'Left': 0.18987715244293213,
#        'Top': 0.6121646761894226},
#       'Confidence': 91.48825073242188},
#      {'BoundingBox': {'Width': 0.03266201168298721,
#        'Height': 0.06630194187164307,
#        'Left': 0.5060991644859314,
#        'Top': 0.6228991746902466},
#       'Confidence': 89.36216735839844},
#      {'BoundingBox': {'Width': 0.01789872720837593,
#        'Height': 0.01117070484906435,
#        'Left': 0.3360276520252228,
#        'Top': 0.5976287722587585},
#       'Confidence': 84.3397445678711},
#      {'BoundingBox': {'Width': 0.019672537222504616,
#        'Height': 0.017576131969690323,
#        'Left': 0.6831117868423462,
#        'Top': 0.6872681379318237},
#       'Confidence': 52.333553314208984}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Adventure',
#     'Confidence': 84.1025619506836,
#     'Instances': [],
#     'Parents': [{'Name': 'Leisure Activities'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 70.16271209716797,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Auto Racing',
#     'Confidence': 74.57184600830078,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Bicycle',
#     'Confidence': 51.132362365722656,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Bike'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Car',
#     'Confidence': 97.30870819091797,
#     'Instances': [{'BoundingBox': {'Width': 0.21830949187278748,
#        'Height': 0.12857627868652344,
#        'Left': 0.5043882727622986,
#        'Top': 0.5775830745697021},
#       'Confidence': 99.40904998779297},
#      {'BoundingBox': {'Width': 0.25184452533721924,
#        'Height': 0.16806751489639282,
#        'Left': 0.18731848895549774,
#        'Top': 0.5584591627120972},
#       'Confidence': 99.36652374267578}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 70.16271209716797,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Kart',
#     'Confidence': 50.6256103515625,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Leisure Activities',
#     'Confidence': 86.37166595458984,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Recreation'}],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Machine',
#     'Confidence': 92.9461669921875,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Offroad',
#     'Confidence': 67.60208892822266,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Person',
#     'Confidence': 51.23291778564453,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Race Car',
#     'Confidence': 78.82340240478516,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Racket',
#     'Confidence': 50.666744232177734,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Rally',
#     'Confidence': 67.60005950927734,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Auto Racing'},
#      {'Name': 'Car'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Offroad'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Rally Racing'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Road',
#     'Confidence': 60.94919967651367,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 70.16271209716797,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Sport',
#     'Confidence': 81.28983306884766,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Sports'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Sports Car',
#     'Confidence': 53.35546112060547,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Tarmac',
#     'Confidence': 56.192928314208984,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [{'Name': 'Asphalt'}],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Tennis',
#     'Confidence': 50.50188064575195,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Tennis Racket',
#     'Confidence': 50.50188064575195,
#     'Instances': [],
#     'Parents': [{'Name': 'Racket'}, {'Name': 'Sport'}, {'Name': 'Tennis'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Tire',
#     'Confidence': 70.16271209716797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 97.30870819091797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 97.30870819091797,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1001,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 92.9461669921875,
#     'Instances': [{'BoundingBox': {'Width': 0.027680253610014915,
#        'Height': 0.09433674067258835,
#        'Left': 0.2753375470638275,
#        'Top': 0.6256739497184753},
#       'Confidence': 94.63712310791016},
#      {'BoundingBox': {'Width': 0.031351663172245026,
#        'Height': 0.06824743747711182,
#        'Left': 0.6068012118339539,
#        'Top': 0.6352626085281372},
#       'Confidence': 91.50110626220703},
#      {'BoundingBox': {'Width': 0.024304568767547607,
#        'Height': 0.08663275092840195,
#        'Left': 0.18985377252101898,
#        'Top': 0.6122201085090637},
#       'Confidence': 90.4898910522461},
#      {'BoundingBox': {'Width': 0.03223872184753418,
#        'Height': 0.06758075207471848,
#        'Left': 0.5059147477149963,
#        'Top': 0.6211300492286682},
#       'Confidence': 90.21552276611328}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Adventure',
#     'Confidence': 78.11859893798828,
#     'Instances': [],
#     'Parents': [{'Name': 'Leisure Activities'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Airport',
#     'Confidence': 50.39855194091797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 89.61070251464844,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Auto Racing',
#     'Confidence': 69.23079681396484,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Car',
#     'Confidence': 97.32791900634766,
#     'Instances': [{'BoundingBox': {'Width': 0.22033175826072693,
#        'Height': 0.12893269956111908,
#        'Left': 0.5040391683578491,
#        'Top': 0.5774861574172974},
#       'Confidence': 99.20211791992188},
#      {'BoundingBox': {'Width': 0.252234548330307,
#        'Height': 0.16827447712421417,
#        'Left': 0.1872451901435852,
#        'Top': 0.5588237643241882},
#       'Confidence': 98.88815307617188}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 89.61070251464844,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Coupe',
#     'Confidence': 53.05419921875,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Sports Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Freeway',
#     'Confidence': 51.33091354370117,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Kart',
#     'Confidence': 51.27419662475586,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Leisure Activities',
#     'Confidence': 78.11859893798828,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Recreation'}],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Machine',
#     'Confidence': 94.380859375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Offroad',
#     'Confidence': 62.67588424682617,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Person',
#     'Confidence': 52.10155487060547,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Race Car',
#     'Confidence': 77.33544921875,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Rally',
#     'Confidence': 62.674869537353516,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Auto Racing'},
#      {'Name': 'Car'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Offroad'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Rally Racing'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Road',
#     'Confidence': 79.76312255859375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Sedan',
#     'Confidence': 50.5254020690918,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 89.6111068725586,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Sport',
#     'Confidence': 77.33544921875,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Sports'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Sports Car',
#     'Confidence': 56.028228759765625,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Tarmac',
#     'Confidence': 71.0193862915039,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [{'Name': 'Asphalt'}],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Tire',
#     'Confidence': 89.61070251464844,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 98.29556274414062,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 98.29556274414062,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 1501,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 94.38045501708984,
#     'Instances': [{'BoundingBox': {'Width': 0.030380677431821823,
#        'Height': 0.06740260869264603,
#        'Left': 0.6071326732635498,
#        'Top': 0.6356459856033325},
#       'Confidence': 96.81065368652344},
#      {'BoundingBox': {'Width': 0.033121634274721146,
#        'Height': 0.06853099167346954,
#        'Left': 0.5056945085525513,
#        'Top': 0.6208177208900452},
#       'Confidence': 94.07728576660156},
#      {'BoundingBox': {'Width': 0.027443695813417435,
#        'Height': 0.09618551284074783,
#        'Left': 0.27559763193130493,
#        'Top': 0.6248815059661865},
#       'Confidence': 92.11923217773438}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Adventure',
#     'Confidence': 74.92520904541016,
#     'Instances': [],
#     'Parents': [{'Name': 'Leisure Activities'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 79.91483306884766,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Auto Racing',
#     'Confidence': 66.33731079101562,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Car',
#     'Confidence': 93.51971435546875,
#     'Instances': [{'BoundingBox': {'Width': 0.21996450424194336,
#        'Height': 0.12839388847351074,
#        'Left': 0.5042089223861694,
#        'Top': 0.5778972506523132},
#       'Confidence': 99.36197662353516},
#      {'BoundingBox': {'Width': 0.2526302933692932,
#        'Height': 0.16881951689720154,
#        'Left': 0.1870669573545456,
#        'Top': 0.558699905872345},
#       'Confidence': 99.27083587646484}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 79.91483306884766,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Clothing',
#     'Confidence': 53.02565002441406,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Apparel'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Coupe',
#     'Confidence': 52.17348861694336,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Sports Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Driving',
#     'Confidence': 50.45048141479492,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Freeway',
#     'Confidence': 50.434505462646484,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Leisure Activities',
#     'Confidence': 76.98481750488281,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Recreation'}],
#     'Categories': [{'Name': 'Travel and Adventure'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Machine',
#     'Confidence': 89.74517822265625,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Offroad',
#     'Confidence': 60.646671295166016,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Person',
#     'Confidence': 57.142757415771484,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Race Car',
#     'Confidence': 77.22084045410156,
#     'Instances': [],
#     'Parents': [{'Name': 'Sport'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Rally',
#     'Confidence': 60.646671295166016,
#     'Instances': [],
#     'Parents': [{'Name': 'Adventure'},
#      {'Name': 'Auto Racing'},
#      {'Name': 'Car'},
#      {'Name': 'Leisure Activities'},
#      {'Name': 'Offroad'},
#      {'Name': 'Race Car'},
#      {'Name': 'Sport'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Rally Racing'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Road',
#     'Confidence': 59.130001068115234,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 79.96200561523438,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Sport',
#     'Confidence': 77.22084045410156,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Sports'}],
#     'Categories': [{'Name': 'Sports'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Sports Car',
#     'Confidence': 54.71356201171875,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Tarmac',
#     'Confidence': 50.86403274536133,
#     'Instances': [],
#     'Parents': [{'Name': 'Road'}],
#     'Aliases': [{'Name': 'Asphalt'}],
#     'Categories': [{'Name': 'Transport and Logistics'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Tire',
#     'Confidence': 79.91483306884766,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 96.30021667480469,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 96.30021667480469,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2002,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 89.697998046875,
#     'Instances': [{'BoundingBox': {'Width': 0.02790973149240017,
#        'Height': 0.0953528955578804,
#        'Left': 0.2750777304172516,
#        'Top': 0.6263927221298218},
#       'Confidence': 95.41616821289062},
#      {'BoundingBox': {'Width': 0.03095254860818386,
#        'Height': 0.06742608547210693,
#        'Left': 0.6068776845932007,
#        'Top': 0.6365416049957275},
#       'Confidence': 94.17494201660156},
#      {'BoundingBox': {'Width': 0.033308982849121094,
#        'Height': 0.06751569360494614,
#        'Left': 0.5059516429901123,
#        'Top': 0.621837854385376},
#       'Confidence': 92.22356414794922},
#      {'BoundingBox': {'Width': 0.0241624116897583,
#        'Height': 0.08672121167182922,
#        'Left': 0.19000203907489777,
#        'Top': 0.6127682328224182},
#       'Confidence': 85.18451690673828},
#      {'BoundingBox': {'Width': 0.018968749791383743,
#        'Height': 0.012325032614171505,
#        'Left': 0.33577099442481995,
#        'Top': 0.5967320799827576},
#       'Confidence': 78.63822937011719}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Accessories',
#     'Confidence': 79.8454360961914,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Accessory'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Adult',
#     'Confidence': 84.9198226928711,
#     'Instances': [{'BoundingBox': {'Width': 0.5359492301940918,
#        'Height': 0.9674533605575562,
#        'Left': 0.0026741684414446354,
#        'Top': 0.03161865100264549},
#       'Confidence': 98.2925796508789}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Alloy Wheel',
#     'Confidence': 57.8992805480957,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Car Wheel'},
#      {'Name': 'Machine'},
#      {'Name': 'Spoke'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Belt',
#     'Confidence': 76.5174789428711,
#     'Instances': [],
#     'Parents': [{'Name': 'Accessories'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Car',
#     'Confidence': 62.63719940185547,
#     'Instances': [{'BoundingBox': {'Width': 0.9954244494438171,
#        'Height': 0.9934945106506348,
#        'Left': 0.0007060481002554297,
#        'Top': 0.00650549354031682},
#       'Confidence': 55.568267822265625}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 57.8992805480957,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Clothing',
#     'Confidence': 92.56401062011719,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Apparel'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Driving',
#     'Confidence': 67.3197250366211,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Face',
#     'Confidence': 86.3639144897461,
#     'Instances': [],
#     'Parents': [{'Name': 'Head'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Formal Wear',
#     'Confidence': 77.59257507324219,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Happy',
#     'Confidence': 60.588985443115234,
#     'Instances': [],
#     'Parents': [{'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Expressions and Emotions'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Head',
#     'Confidence': 86.3639144897461,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Jewelry',
#     'Confidence': 51.88745880126953,
#     'Instances': [],
#     'Parents': [{'Name': 'Accessories'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Machine',
#     'Confidence': 59.08696365356445,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Male',
#     'Confidence': 84.9198226928711,
#     'Instances': [{'BoundingBox': {'Width': 0.5359492301940918,
#        'Height': 0.9674533605575562,
#        'Left': 0.0026741684414446354,
#        'Top': 0.03161865100264549},
#       'Confidence': 98.2925796508789}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Man',
#     'Confidence': 84.9198226928711,
#     'Instances': [{'BoundingBox': {'Width': 0.5359492301940918,
#        'Height': 0.9674533605575562,
#        'Left': 0.0026741684414446354,
#        'Top': 0.03161865100264549},
#       'Confidence': 98.2925796508789}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Nature',
#     'Confidence': 51.1553955078125,
#     'Instances': [],
#     'Parents': [{'Name': 'Outdoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Necklace',
#     'Confidence': 51.307159423828125,
#     'Instances': [{'BoundingBox': {'Width': 0.02571687661111355,
#        'Height': 0.043827228248119354,
#        'Left': 0.2775474190711975,
#        'Top': 0.7153632044792175},
#       'Confidence': 61.56941223144531}],
#     'Parents': [{'Name': 'Accessories'}, {'Name': 'Jewelry'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Officer',
#     'Confidence': 50.17763900756836,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Profession'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Outdoors',
#     'Confidence': 51.1553955078125,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Person',
#     'Confidence': 93.19430541992188,
#     'Instances': [{'BoundingBox': {'Width': 0.5359492301940918,
#        'Height': 0.9674533605575562,
#        'Left': 0.0026741684414446354,
#        'Top': 0.03161865100264549},
#       'Confidence': 98.2925796508789}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Photography',
#     'Confidence': 86.36184692382812,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Photo'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Portrait',
#     'Confidence': 86.36184692382812,
#     'Instances': [],
#     'Parents': [{'Name': 'Face'},
#      {'Name': 'Head'},
#      {'Name': 'Person'},
#      {'Name': 'Photography'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Sedan',
#     'Confidence': 51.89546585083008,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Shirt',
#     'Confidence': 86.31616973876953,
#     'Instances': [{'BoundingBox': {'Width': 0.5418640375137329,
#        'Height': 0.475791335105896,
#        'Left': 0.0006192572764120996,
#        'Top': 0.5238115787506104},
#       'Confidence': 82.4768295288086}],
#     'Parents': [{'Name': 'Clothing'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Smile',
#     'Confidence': 60.48728942871094,
#     'Instances': [],
#     'Parents': [{'Name': 'Face'},
#      {'Name': 'Happy'},
#      {'Name': 'Head'},
#      {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Expressions and Emotions'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 57.99853515625,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Suv',
#     'Confidence': 50.074249267578125,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Tie',
#     'Confidence': 76.4856185913086,
#     'Instances': [],
#     'Parents': [{'Name': 'Accessories'}, {'Name': 'Formal Wear'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Tire',
#     'Confidence': 57.8992805480957,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 80.70372772216797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 80.70372772216797,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Water',
#     'Confidence': 50.55883026123047,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 2502,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 58.987709045410156,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 3003,
#    'Label': {'Name': 'Accessories',
#     'Confidence': 85.00138092041016,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Accessory'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 3003,
#    'Label': {'Name': 'Adult',
#     'Confidence': 94.13966369628906,
#     'Instances': [{'BoundingBox': {'Width': 0.5390215516090393,
#        'Height': 0.9698893427848816,
#        'Left': 0.0013683459255844355,
#        'Top': 0.02992655523121357},
#       'Confidence': 98.70779418945312}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
# ...
#    'Label': {'Name': 'Car Wheel',
#     'Confidence': 53.852569580078125,
#     'Instances': [],
#     'Parents': [{'Name': 'Car'},
#      {'Name': 'Machine'},
#      {'Name': 'Tire'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'},
#      {'Name': 'Wheel'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Cushion',
#     'Confidence': 54.547508239746094,
#     'Instances': [],
#     'Parents': [{'Name': 'Home Decor'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Driving',
#     'Confidence': 90.18586730957031,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Face',
#     'Confidence': 69.15574645996094,
#     'Instances': [],
#     'Parents': [{'Name': 'Head'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Finger',
#     'Confidence': 79.41393280029297,
#     'Instances': [],
#     'Parents': [{'Name': 'Body Part'}, {'Name': 'Hand'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Hand',
#     'Confidence': 79.41393280029297,
#     'Instances': [],
#     'Parents': [{'Name': 'Body Part'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Head',
#     'Confidence': 69.17609405517578,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Home Decor',
#     'Confidence': 54.547508239746094,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Machine',
#     'Confidence': 69.64710235595703,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Male',
#     'Confidence': 84.80171966552734,
#     'Instances': [{'BoundingBox': {'Width': 0.667975902557373,
#        'Height': 0.8697541356086731,
#        'Left': 0.048243023455142975,
#        'Top': 0.12988516688346863},
#       'Confidence': 98.3798599243164}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Man',
#     'Confidence': 84.80171966552734,
#     'Instances': [{'BoundingBox': {'Width': 0.667975902557373,
#        'Height': 0.8697541356086731,
#        'Left': 0.048243023455142975,
#        'Top': 0.12988516688346863},
#       'Confidence': 98.3798599243164}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Person',
#     'Confidence': 92.58199310302734,
#     'Instances': [{'BoundingBox': {'Width': 0.667975902557373,
#        'Height': 0.8697541356086731,
#        'Left': 0.048243023455142975,
#        'Top': 0.12988516688346863},
#       'Confidence': 98.3798599243164}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Photography',
#     'Confidence': 53.3052864074707,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Photo'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Spoke',
#     'Confidence': 53.7319221496582,
#     'Instances': [],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Tire',
#     'Confidence': 53.852569580078125,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 97.05442810058594,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 97.05442810058594,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 13513,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 69.64710235595703,
#     'Instances': [{'BoundingBox': {'Width': 0.08789829909801483,
#        'Height': 0.06344252824783325,
#        'Left': 0.4334396421909332,
#        'Top': 0.4749267101287842},
#       'Confidence': 64.68038940429688}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Adult',
#     'Confidence': 94.767333984375,
#     'Instances': [{'BoundingBox': {'Width': 0.7011072039604187,
#        'Height': 0.8581053018569946,
#        'Left': 0.03513294458389282,
#        'Top': 0.13984322547912598},
#       'Confidence': 96.99430084228516}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Body Part',
#     'Confidence': 52.66291809082031,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Car',
#     'Confidence': 66.66822814941406,
#     'Instances': [{'BoundingBox': {'Width': 0.40975967049598694,
#        'Height': 0.18147723376750946,
#        'Left': 0.40428462624549866,
#        'Top': 0.36311620473861694},
#       'Confidence': 62.5345344543457}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Cushion',
#     'Confidence': 51.865203857421875,
#     'Instances': [],
#     'Parents': [{'Name': 'Home Decor'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Driving',
#     'Confidence': 95.57192993164062,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Face',
#     'Confidence': 91.31832122802734,
#     'Instances': [],
#     'Parents': [{'Name': 'Head'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Finger',
#     'Confidence': 52.66291809082031,
#     'Instances': [],
#     'Parents': [{'Name': 'Body Part'}, {'Name': 'Hand'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Hand',
#     'Confidence': 52.66291809082031,
#     'Instances': [],
#     'Parents': [{'Name': 'Body Part'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Head',
#     'Confidence': 91.4888687133789,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Home Decor',
#     'Confidence': 51.865203857421875,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Machine',
#     'Confidence': 73.66073608398438,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Male',
#     'Confidence': 92.56245422363281,
#     'Instances': [{'BoundingBox': {'Width': 0.7011072039604187,
#        'Height': 0.8581053018569946,
#        'Left': 0.03513294458389282,
#        'Top': 0.13984322547912598},
#       'Confidence': 96.99430084228516}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Man',
#     'Confidence': 92.56245422363281,
#     'Instances': [{'BoundingBox': {'Width': 0.7011072039604187,
#        'Height': 0.8581053018569946,
#        'Left': 0.03513294458389282,
#        'Top': 0.13984322547912598},
#       'Confidence': 96.99430084228516}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Person',
#     'Confidence': 96.4510498046875,
#     'Instances': [{'BoundingBox': {'Width': 0.7011072039604187,
#        'Height': 0.8581053018569946,
#        'Left': 0.03513294458389282,
#        'Top': 0.13984322547912598},
#       'Confidence': 96.99430084228516}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Photography',
#     'Confidence': 52.796791076660156,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Photo'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Portrait',
#     'Confidence': 50.579349517822266,
#     'Instances': [],
#     'Parents': [{'Name': 'Face'},
#      {'Name': 'Head'},
#      {'Name': 'Person'},
#      {'Name': 'Photography'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 98.01197814941406,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 98.01197814941406,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14014,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 73.66073608398438,
#     'Instances': [{'BoundingBox': {'Width': 0.08430890738964081,
#        'Height': 0.06350716203451157,
#        'Left': 0.4331537187099457,
#        'Top': 0.4757592976093292},
#       'Confidence': 74.99561309814453}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Adult',
#     'Confidence': 97.55330657958984,
#     'Instances': [{'BoundingBox': {'Width': 0.7237803339958191,
#        'Height': 0.8613598346710205,
#        'Left': 0.03689233958721161,
#        'Top': 0.13687393069267273},
#       'Confidence': 97.57152557373047}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Car',
#     'Confidence': 74.12898254394531,
#     'Instances': [{'BoundingBox': {'Width': 0.4117881655693054,
#        'Height': 0.19689585268497467,
#        'Left': 0.4045712351799011,
#        'Top': 0.35958999395370483},
#       'Confidence': 75.45954895019531}],
#     'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#     'Aliases': [{'Name': 'Automobile'}],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Cushion',
#     'Confidence': 52.976863861083984,
#     'Instances': [],
#     'Parents': [{'Name': 'Home Decor'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Driving',
#     'Confidence': 99.26964569091797,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'},
#      {'Name': 'Transportation'},
#      {'Name': 'Vehicle'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Face',
#     'Confidence': 93.41753387451172,
#     'Instances': [],
#     'Parents': [{'Name': 'Head'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Head',
#     'Confidence': 93.44110107421875,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Home Decor',
#     'Confidence': 52.976863861083984,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Machine',
#     'Confidence': 62.280128479003906,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Tools and Machinery'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Male',
#     'Confidence': 97.55330657958984,
#     'Instances': [{'BoundingBox': {'Width': 0.7237803339958191,
#        'Height': 0.8613598346710205,
#        'Left': 0.03689233958721161,
#        'Top': 0.13687393069267273},
#       'Confidence': 97.57152557373047}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Man',
#     'Confidence': 97.55330657958984,
#     'Instances': [{'BoundingBox': {'Width': 0.7237803339958191,
#        'Height': 0.8613598346710205,
#        'Left': 0.03689233958721161,
#        'Top': 0.13687393069267273},
#       'Confidence': 97.57152557373047}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Person',
#     'Confidence': 99.49728393554688,
#     'Instances': [{'BoundingBox': {'Width': 0.7237803339958191,
#        'Height': 0.8613598346710205,
#        'Left': 0.03689233958721161,
#        'Top': 0.13687393069267273},
#       'Confidence': 97.57152557373047}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Photography',
#     'Confidence': 54.820152282714844,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Photo'}],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Portrait',
#     'Confidence': 54.820152282714844,
#     'Instances': [],
#     'Parents': [{'Name': 'Face'},
#      {'Name': 'Head'},
#      {'Name': 'Person'},
#      {'Name': 'Photography'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Transportation',
#     'Confidence': 99.26964569091797,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Vehicle',
#     'Confidence': 99.26964569091797,
#     'Instances': [],
#     'Parents': [{'Name': 'Transportation'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}},
#   {'Timestamp': 14514,
#    'Label': {'Name': 'Wheel',
#     'Confidence': 62.280128479003906,
#     'Instances': [{'BoundingBox': {'Width': 0.08287858963012695,
#        'Height': 0.061490971595048904,
#        'Left': 0.43336501717567444,
#        'Top': 0.4773660898208618},
#       'Confidence': 60.54067611694336}],
#     'Parents': [{'Name': 'Machine'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Vehicles and Automotive'}]}}],
#  'LabelModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '1246e002-39f4-4528-be08-9f919c76c34e',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1246e002-39f4-4528-be08-9f919c76c34e',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '200066',
#    'date': 'Sun, 18 Jun 2023 23:22:33 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### Display names of recognized objects in the video

# %%
flaggedObjectsInVideo = ["Car"]

theObjects = {}

# Display timestamps and objects detected at that time
strDetail = "Objects detected in video<br>=======================================<br>"
strOverall = "Objects in the overall video:<br>=======================================<br>"

# Objects detected in each frame
for obj in getObjectDetection['Labels']:
    ts = obj ["Timestamp"]
    cconfidence = obj['Label']["Confidence"]
    oname = obj['Label']["Name"]
    
    if(oname in flaggedObjectsInVideo):
        print("Found flagged object at {} ms: {} (Confidence: {})".format(ts, oname, round(cconfidence,2)))
    
    strDetail = strDetail + "At {} ms: {} (Confidence: {})<br>".format(ts, oname, round(cconfidence,2))
    if oname in theObjects:
        cojb = theObjects[oname]
        theObjects[oname] = {"Name" : oname, "Count": 1+cojb["Count"]}
    else:
        theObjects[oname] = {"Name" : oname, "Count": 1}

# Unique objects detected in video
for theObject in theObjects:
    strOverall = strOverall + "Name: {}, Count: {}<br>".format(theObject, theObjects[theObject]["Count"])

# Display results
display(HTML(strOverall))
# Out:
# Found flagged object at 0 ms: Car (Confidence: 60.74)
# Found flagged object at 500 ms: Car (Confidence: 95.09)
# Found flagged object at 1001 ms: Car (Confidence: 97.31)
# Found flagged object at 1501 ms: Car (Confidence: 97.33)
# Found flagged object at 2002 ms: Car (Confidence: 93.52)
# Found flagged object at 2502 ms: Car (Confidence: 62.64)
# Found flagged object at 3003 ms: Car (Confidence: 58.07)
# Found flagged object at 3503 ms: Car (Confidence: 56.56)
# Found flagged object at 4004 ms: Car (Confidence: 54.79)
# Found flagged object at 4504 ms: Car (Confidence: 54.3)
# Found flagged object at 5005 ms: Car (Confidence: 59.85)
# Found flagged object at 5505 ms: Car (Confidence: 93.01)
# Found flagged object at 6006 ms: Car (Confidence: 97.3)
# Found flagged object at 6506 ms: Car (Confidence: 97.17)
# Found flagged object at 7007 ms: Car (Confidence: 92.87)
# Found flagged object at 7507 ms: Car (Confidence: 58.27)
# Found flagged object at 8008 ms: Car (Confidence: 54.38)
# Found flagged object at 8508 ms: Car (Confidence: 51.89)
# Found flagged object at 9009 ms: Car (Confidence: 54.56)
# Found flagged object at 9509 ms: Car (Confidence: 58.65)
# Found flagged object at 10010 ms: Car (Confidence: 93.49)
# Found flagged object at 10510 ms: Car (Confidence: 97.82)
# Found flagged object at 11011 ms: Car (Confidence: 99.99)
# Found flagged object at 11511 ms: Car (Confidence: 99.71)
# Found flagged object at 12012 ms: Car (Confidence: 99.18)
# Found flagged object at 12512 ms: Car (Confidence: 94.08)
# Found flagged object at 13013 ms: Car (Confidence: 93.01)
# Found flagged object at 13513 ms: Car (Confidence: 77.45)
# Found flagged object at 14014 ms: Car (Confidence: 66.67)
# Found flagged object at 14514 ms: Car (Confidence: 74.13)
# Objects in the overall video:<br>=======================================<br>Name: Alloy Wheel, Count: 28<br>Name: Animal, Count: 1<br>Name: Baseball, Count: 1<br>Name: Car, Count: 30<br>Name: Car Wheel, Count: 28<br>Name: Clothing, Count: 13<br>Name: Electrical Device, Count: 1<br>Name: Electronics, Count: 2<br>Name: Glove, Count: 1<br>Name: Gray, Count: 1<br>Name: Leisure Activities, Count: 9<br>Name: Machine, Count: 30<br>Name: Mammal, Count: 1<br>Name: Nature, Count: 5<br>Name: Outdoors, Count: 10<br>Name: Person, Count: 25<br>Name: Racket, Count: 3<br>Name: Road, Count: 12<br>Name: Snow, Count: 1<br>Name: Spoke, Count: 28<br>Name: Sport, Count: 9<br>Name: Tennis, Count: 3<br>Name: Tennis Racket, Count: 3<br>Name: Text, Count: 1<br>Name: Tire, Count: 28<br>Name: Transportation, Count: 30<br>Name: Vehicle, Count: 30<br>Name: Wheel, Count: 30<br>Name: Adventure, Count: 8<br>Name: Auto Racing, Count: 6<br>Name: Bicycle, Count: 2<br>Name: Offroad, Count: 7<br>Name: Race Car, Count: 8<br>Name: Rally, Count: 6<br>Name: Sports Car, Count: 16<br>Name: Tarmac, Count: 8<br>Name: Kart, Count: 2<br>Name: Airport, Count: 3<br>Name: Coupe, Count: 14<br>Name: Freeway, Count: 2<br>Name: Sedan, Count: 10<br>Name: Driving, Count: 17<br>Name: Accessories, Count: 12<br>Name: Adult, Count: 14<br>Name: Belt, Count: 10<br>Name: Face, Count: 14<br>Name: Formal Wear, Count: 5<br>Name: Happy, Count: 6<br>Name: Head, Count: 14<br>Name: Jewelry, Count: 6<br>Name: Male, Count: 14<br>Name: Man, Count: 14<br>Name: Necklace, Count: 1<br>Name: Officer, Count: 2<br>Name: Photography, Count: 14<br>Name: Portrait, Count: 13<br>Name: Shirt, Count: 11<br>Name: Smile, Count: 6<br>Name: Suv, Count: 5<br>Name: Tie, Count: 5<br>Name: Water, Count: 4<br>Name: Body Part, Count: 12<br>Name: Coat, Count: 3<br>Name: Cushion, Count: 11<br>Name: Glasses, Count: 3<br>Name: Home Decor, Count: 11<br>Name: Jacket, Count: 3<br>Name: Laughing, Count: 2<br>Name: Mouth, Count: 2<br>Name: Seat Belt, Count: 5<br>Name: Sitting, Count: 7<br>Name: Sunglasses, Count: 4<br>Name: Teeth, Count: 2<br>Name: Baseball Cap, Count: 2<br>Name: Beard, Count: 2<br>Name: Cap, Count: 2<br>Name: Captain, Count: 1<br>Name: Dress Shirt, Count: 3<br>Name: Earring, Count: 1<br>Name: Hat, Count: 2<br>Name: Headrest, Count: 2<br>Name: Lake, Count: 2<br>Name: Necktie, Count: 2<br>Name: Passenger Car, Count: 1<br>Name: Selfie, Count: 2<br>Name: Senior Citizen, Count: 5<br>Name: Suit, Count: 2<br>Name: Windshield, Count: 4<br>Name: Yacht, Count: 2<br>Name: Angry, Count: 1<br>Name: Finger, Count: 10<br>Name: Frown, Count: 1<br>Name: Hand, Count: 10<br>Name: Sad, Count: 1<br>Name: Smoke, Count: 1<br>Name: Baby, Count: 5<br>Name: Fun, Count: 4<br>Name: Vacation, Count: 3<br>Name: Architecture, Count: 3<br>Name: Building, Count: 3<br>Name: License Plate, Count: 7<br>Name: Shelter, Count: 3<br>Name: Bumper, Count: 2<br>Name: Car Dealership, Count: 3<br>Name: City, Count: 1<br>Name: Office Building, Count: 2<br>Name: Police Station, Count: 2<br>Name: Terminal, Count: 2<br>Name: Urban, Count: 1<br>Name: Car Show, Count: 1<br>Name: Indoors, Count: 1<br>Name: Mobile Phone, Count: 1<br>Name: Phone, Count: 1<br>Name: Ring, Count: 2<br>Name: Wrist, Count: 2<br>Name: Wristwatch, Count: 1<br>Name: Logo, Count: 5<br>Name: Car - Exterior, Count: 6<br>Name: Car Mirror, Count: 6<br>Name: Coil, Count: 1<br>Name: Gas Station, Count: 2<br>Name: Headlight, Count: 5<br>Name: Hubcap, Count: 2<br>Name: Pump, Count: 2<br>Name: Rotor, Count: 1<br>Name: Spiral, Count: 1<br>Name: Tar, Count: 1<br>Name: Maroon, Count: 1<br>Name: VR Headset, Count: 2<br>Name: Mirror, Count: 3<br>

# %% [markdown]
# #### Show video in the player

# %%
# Show video in a player

s3VideoUrl = s3.generate_presigned_url('get_object', Params={'Bucket': bucketName, 'Key': videoName})

videoTag = "<video controls='controls' autoplay width='640' height='360' name='Video' src='{0}'></video>".format(s3VideoUrl)

videoui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(videoTag)

display(HTML(videoui))
# Out:
# <table><tr><td style='vertical-align: top'><video controls='controls' autoplay width='640' height='360' name='Video' src='https://aws-rek-immersionday-us-east-1.s3.amazonaws.com/media/object-detection/GrandTour720.mp4?AWSAccessKeyId=ASIA6AX7UATUEHFSDD74&Signature=ajC8yfKzv37CuzTi1YMvRfXbJ6s%3D&x-amz-security-token=IQoJb3JpZ2luX2VjECcaCXVzLWVhc3QtMSJHMEUCIQC%2BsyMqdGPe67OFtj5x2XHJmty0plTVN1i4zMK8TxfPHwIgTAZOaEwOUwMZ0RT0fkl9uTfe3cE9ee7slgKehlsp1PYqigMIgP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARABGgw5NjM2ODI1MDE4NjQiDP%2Fw0ytWD4VFo8Gn9yreAnq%2BiFqp0LE%2FwwWqpLiM1qa7GkmLwzQoVoSDf41eqR8LTe8XZGQqJHK%2FHUPo6MQBnH0%2BIeiZs2cgTedr1Ik0url5AryD6OEdUWTzwzF1FSDgmErqckXy2%2BUD9BOArwESdfHazAEJMMcJ919CM5fMDUGdBTswNiKf7uBYXxGNkBpLVicErtLA6TuEKUsXHxs8aOxHNec2xvwnyvIPI8l0zBhaS1MlKTyjnku2Q6WcVniLHrBCulv0XYmMvamIb2GqFc1J2oL0FdHODTkmFvSN6UUFP8SoR7LONZ8N%2FtzGl97%2FYJgcFVwc76fWi8tVHtc8AyyPZwFeJGSdxgI1F90QZTQw39Eu7801kvjd%2BGtpA9saGfmq7wBWIJnX0DT8i3vuD9uDkEkQ8JMzzbAQv5nyq7ex9uwUxCjhGFDo6leBpQyep6YPwNeMjDRwXAp8zNfyS88vMppiXhK4fCywg7YQMMmWvqQGOpsBUcNSbhpyIRY2ckpwHX%2BBoC64t0%2Blo5%2FKfI7gP51tpKgFlycmrBrmzDME19sgvi4J4MOiMxQwBoEiKZr0Hwmf55VyrFjWkj%2BhL0bBsBd7K%2B8P1SHX9%2FRC7OC3Jq%2FNuupdhUWSaj8aP7yqH7S8VCZvZHc8lzvXvTHwGeN7asptFzqi%2BdJhN5QVuW4QmFDV5hRcfA8RqARvHTyP86E%3D&Expires=1687134154'></video></td></tr></table>

# %%
listui = "<table><tr><td style='vertical-align: top'>{}</td></tr></table>".format(strDetail)
display(HTML(listui))
# Out:
# <table><tr><td style='vertical-align: top'>Objects detected in video<br>=======================================<br>At 0 ms: Alloy Wheel (Confidence: 57.65)<br>At 0 ms: Animal (Confidence: 50.82)<br>At 0 ms: Baseball (Confidence: 50.29)<br>At 0 ms: Car (Confidence: 60.74)<br>At 0 ms: Car Wheel (Confidence: 57.65)<br>At 0 ms: Clothing (Confidence: 52.09)<br>At 0 ms: Electrical Device (Confidence: 51.35)<br>At 0 ms: Electronics (Confidence: 51.23)<br>At 0 ms: Glove (Confidence: 52.09)<br>At 0 ms: Gray (Confidence: 76.63)<br>At 0 ms: Leisure Activities (Confidence: 55.94)<br>At 0 ms: Machine (Confidence: 59.92)<br>At 0 ms: Mammal (Confidence: 50.65)<br>At 0 ms: Nature (Confidence: 51.73)<br>At 0 ms: Outdoors (Confidence: 51.73)<br>At 0 ms: Person (Confidence: 51.8)<br>At 0 ms: Racket (Confidence: 56.78)<br>At 0 ms: Road (Confidence: 52.84)<br>At 0 ms: Snow (Confidence: 51.13)<br>At 0 ms: Spoke (Confidence: 57.65)<br>At 0 ms: Sport (Confidence: 58.66)<br>At 0 ms: Tennis (Confidence: 53.72)<br>At 0 ms: Tennis Racket (Confidence: 53.72)<br>At 0 ms: Text (Confidence: 55.93)<br>At 0 ms: Tire (Confidence: 57.65)<br>At 0 ms: Transportation (Confidence: 60.74)<br>At 0 ms: Vehicle (Confidence: 60.74)<br>At 0 ms: Wheel (Confidence: 59.92)<br>At 500 ms: Adventure (Confidence: 78.92)<br>At 500 ms: Alloy Wheel (Confidence: 82.33)<br>At 500 ms: Auto Racing (Confidence: 69.31)<br>At 500 ms: Bicycle (Confidence: 50.55)<br>At 500 ms: Car (Confidence: 95.09)<br>At 500 ms: Car Wheel (Confidence: 82.33)<br>At 500 ms: Leisure Activities (Confidence: 83.67)<br>At 500 ms: Machine (Confidence: 90.37)<br>At 500 ms: Offroad (Confidence: 62.72)<br>At 500 ms: Person (Confidence: 50.76)<br>At 500 ms: Race Car (Confidence: 73.7)<br>At 500 ms: Racket (Confidence: 51.62)<br>At 500 ms: Rally (Confidence: 62.71)<br>At 500 ms: Road (Confidence: 65.34)<br>At 500 ms: Spoke (Confidence: 82.33)<br>At 500 ms: Sport (Confidence: 78.87)<br>At 500 ms: Sports Car (Confidence: 50.61)<br>At 500 ms: Tarmac (Confidence: 52.6)<br>At 500 ms: Tennis (Confidence: 51.28)<br>At 500 ms: Tennis Racket (Confidence: 51.28)<br>At 500 ms: Tire (Confidence: 82.33)<br>At 500 ms: Transportation (Confidence: 95.09)<br>At 500 ms: Vehicle (Confidence: 95.09)<br>At 500 ms: Wheel (Confidence: 90.37)<br>At 1001 ms: Adventure (Confidence: 84.1)<br>At 1001 ms: Alloy Wheel (Confidence: 70.16)<br>At 1001 ms: Auto Racing (Confidence: 74.57)<br>At 1001 ms: Bicycle (Confidence: 51.13)<br>At 1001 ms: Car (Confidence: 97.31)<br>At 1001 ms: Car Wheel (Confidence: 70.16)<br>At 1001 ms: Kart (Confidence: 50.63)<br>At 1001 ms: Leisure Activities (Confidence: 86.37)<br>At 1001 ms: Machine (Confidence: 92.95)<br>At 1001 ms: Offroad (Confidence: 67.6)<br>At 1001 ms: Person (Confidence: 51.23)<br>At 1001 ms: Race Car (Confidence: 78.82)<br>At 1001 ms: Racket (Confidence: 50.67)<br>At 1001 ms: Rally (Confidence: 67.6)<br>At 1001 ms: Road (Confidence: 60.95)<br>At 1001 ms: Spoke (Confidence: 70.16)<br>At 1001 ms: Sport (Confidence: 81.29)<br>At 1001 ms: Sports Car (Confidence: 53.36)<br>At 1001 ms: Tarmac (Confidence: 56.19)<br>At 1001 ms: Tennis (Confidence: 50.5)<br>At 1001 ms: Tennis Racket (Confidence: 50.5)<br>At 1001 ms: Tire (Confidence: 70.16)<br>At 1001 ms: Transportation (Confidence: 97.31)<br>At 1001 ms: Vehicle (Confidence: 97.31)<br>At 1001 ms: Wheel (Confidence: 92.95)<br>At 1501 ms: Adventure (Confidence: 78.12)<br>At 1501 ms: Airport (Confidence: 50.4)<br>At 1501 ms: Alloy Wheel (Confidence: 89.61)<br>At 1501 ms: Auto Racing (Confidence: 69.23)<br>At 1501 ms: Car (Confidence: 97.33)<br>At 1501 ms: Car Wheel (Confidence: 89.61)<br>At 1501 ms: Coupe (Confidence: 53.05)<br>At 1501 ms: Freeway (Confidence: 51.33)<br>At 1501 ms: Kart (Confidence: 51.27)<br>At 1501 ms: Leisure Activities (Confidence: 78.12)<br>At 1501 ms: Machine (Confidence: 94.38)<br>At 1501 ms: Offroad (Confidence: 62.68)<br>At 1501 ms: Person (Confidence: 52.1)<br>At 1501 ms: Race Car (Confidence: 77.34)<br>At 1501 ms: Rally (Confidence ...

# %% [markdown]
# ***
# ### References
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_DetectLabels.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_StartLabelDetection.html
# - https://docs.aws.amazon.com/rekognition/latest/dg/API_GetLabelDetection.html
#
# ***

# %% [markdown]
# You have successfully used Amazon Rekognition to identify specific objects in images and videos. In the next module,nyou will learn how to recognize explicit, suggestive or violent content in the images and videos.
